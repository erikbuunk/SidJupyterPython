# %% [raw]
# ---
# title: "Web scraping with Python"
# always_allow_html: yes
# output:
#   html_document:
#     highlight: tango
#     toc: true
#     toc_float:
#       collapsed: true
# ---

# %% [markdown]
# <style type="text/css">
# pre code {
#     display: block;
#     unicode-bidi: embed;
#     font-family: monospace;
#     white-space: pre;
#     max-height: 400px;
#     overflow-x: scroll;
#     overflow-y: scroll;
#     }
# </style>

# %%
## This part is optional; it sets some printing options
## that make output look nicer.
from pprint import pprint as print
import pandas as pd
pd.set_option('display.width', 133)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_columns', 5)

# %% [markdown]
# ## Setup instructions
#
# ###  Install the Anaconda Python distribution
# If using your own computer please install the Anaconda Python
# distribution from
# [https://www.anaconda.com/download/](https://www.anaconda.com/download/).
# (Note that Python version $\leq$ 3.0 differs considerably from more
# recent releases. For this workshop you will need version $\geq$ 3.4.)
#
# Accepting the defaults proposed by the Anaconda installer is generally
# recommended.
#
# ### Workshop notes
# The class notes for this workshop are available on our website at
# [dss.iq.harvard.edu](https://dss.iq.harvard.edu) under `Workshop
# Materials ==> Python Workshop Materials => Python Web Scraping`. Click
# the `All workshop materials` link to download the workshop materials.
#
# Extract the `PythonWebScraping.zip` directory (`Right-click => Extract All` on
# Windows, `double-click` on Mac).
#
# Start the `Jupyter Notebook` application and open the
# `Exercises.ipynb` file in the `PythonWebScraping` folder you
# downloaded previously. You may also wish to start a new notebook for
# your own notes.

# %% [markdown]
# ## Workshop goals and approach
# In this workshop you will
#
# * learn basic web scraping principles and techniques,
# * learn how to use the `requests` package in Python,
# * practice making requests and manipulating responses from the server.
#
# This workshop is relatively *informal*, *example-oriented*, and
# *hands-on*. We will learn by working through an example web scraping
# project.
#
# Note that this is **not** an introductory workshop. Familiarity with
# Python, including but not limited to knowledge of lists and
# dictionaries, indexing, and loops and / or comprehensions is assumed.
# If you need an introduction to Python or a refresher, we recommend the
# [IQSS Introduction to Python](https://dss.iq.harvard.edu/workshop-materials#widget-0).
#
# Note also that this workshop will not teach you everything you need to
# know in order to retrieve data from any web service you might wish to
# scrape. You can expect to learn just enough to be dangerous.
#
# ## Preliminary questions
#
# ### What is web scraping?
# Web scraping is the activity of automating retrieval of information
# from a web service designed for human interaction.
#
# ### Is web scraping legal? Is it ethical?
# It depends. If you have legal questions seek legal counsel. You can
# mitigate some ethical issues by building delays and restrictions into
# your web scraping program so as to avoid impacting the availability of
# the web service for other users or the cost of hosting the service for
# the service provider.

# %% [markdown]
# ## Example project overview and goals
# In this workshop I will demonstrate web scraping techniques using the
# Collections page at
# <https://www.harvardartmuseums.org/collections> and let you use
# the skills you'll learn to retrieve information from other parts of
# the Harvard Art Museums website.
#
# The basic strategy is pretty much the same for most scraping projects.
# We will use our web browser (Chrome or Firefox recommended) to examine
# the page you wish to retrieve data from, and copy/paste information
# from your web browser into your scraping program.
#
# ## Take shortcuts if you can
# We wish to extract information from
# <https://www.harvardartmuseums.org/collections>. Like most
# modern web pages, a lot goes on behind the scenes to produce the page
# we see in our browser. Our goal is to pull back the curtain to see
# what the website does when we interact with it. Once we see how the
# website works we can start retrieving data from it. If we are lucky
# we'll find a resource that returns the data we're looking for in a
# structured format like [JSON](https://json.org/) or
# [XML](https://en.wikipedia.org/wiki/XML).

# %% [markdown]
# ### Examining the structure of our target web service
#
# We start by opening the collections web page in a web browser and
# inspecting it.
#
# ![](img/dev_tools.png)
#
# ![](img/dev_tools_pane.png)
#
# If we scroll down to the bottom of the Collections page, we'll see a
# button that says "Load More". Let's see what happens when we click on
# that button. To do so, click on "Network" in the developer tools
# window, then click the "Load More Collections" button. You should see
# a list of requests that were made as a result of clicking that button,
# as shown below.
#
# ![](img/dev_tools_network.png)

# %% [markdown]
# If we look at that second request, the one to a script named
# `browse`, we'll see that it returns all the information we need, in
# a convenient format called `JSON`. All we need to retrieve collection
# data is call make `GET` requests to
# <https://www.harvardartmuseums.org/browse> with the correct
# parameters.
#
# ### Making requests using python
# The URL we want to retrieve data from has the following structure
#
#     scheme                    domain    path  parameters
#      https www.harvardartmuseums.org  browse  load_amount=10&offset=0
#
# It is often convenient to create variables containing the domain(s)
# and path(s) you'll be working with, as this allows you to swap out
# paths and parameters as needed. Note that the path is separated from
# the domain with `/` and the parameters are separated from the path
# with `?`. If there are multiple parameters they are separated from
# each other with a `&`.
#
# For example, we can define the domain and path of the collections URL
# as follows:

# %%
museum_domain = 'https://www.harvardartmuseums.org'
collection_path = 'browse'

collection_url = (museum_domain
                  + "/"
                  + collection_path)

print(collection_url)
# Out:
# 'https://www.harvardartmuseums.org/browse'

# %% [markdown]
# Note that we omit the parameters here because it is usually easier to
# pass them as a `dict` when using the `requests` library in Python.
# This will become clearer shortly.
#
# Now that we've constructed the URL we wish interact with we're ready
# to make our first request in Python.

# %%
import requests

collections1 = requests.get(
    collection_url,
    params = {'load_amount': 10,
                  'offset': 0}
)

# %%
# ### Parsing JSON data
# We already know from inspecting network traffic in our web
# browser that this URL returns JSON, but we can use Python to verify
# this assumption.
collections1.headers['Content-Type']
# Out:
# 'application/json'

# %% [markdown]
# Since JSON is a structured data format, parsing it into python data
# structures is easy. In fact, there's a method for that!

# %%
collections1 = collections1.json()
print(collections1)
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/object?apikey=67d9edc0-e6a3-11e3-9798-57275476509a&sort=rank&sortorder=asc&from=0&size=10&page=2',
#           'page': 1,
#           'pages': 23398,
#           'totalrecords': 233977,
#           'totalrecordsperquery': 10},
#  'records': [{'accessionmethod': 'Gift',
#               'accessionyear': 1957,
#               'accesslevel': 1,
#               'century': '3rd millennium BCE',
#               'classification': 'Seals',
#               'classificationid': 189,
#               'colorcount': 7,
#               'colors': [{'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.38343042071197,
#                           'spectrum': '#3db657'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.30718446601942,
#                           'spectrum': '#2eb45d'},
#                          {'color': '#646464',
#                           'css3': '#696969',
#                           'hue': 'Grey',
#                           'percent': 0.19831715210356,
#                           'spectrum': '#7866ad'},
#                          {'color': '#191919',
#                           'css3': '#000000',
#                           'hue': 'Grey',
#                           'percent': 0.098899676375405,
#                           'spectrum': '#1eb264'},
#                          {'color': '#7d7d7d',
#                           'css3': '#808080',
#                           'hue': 'Grey',
#                           'percent': 0.0099029126213592,
#                           'spectrum': '#8362aa'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.0020711974110032,
#                           'spectrum': '#8761aa'},
#                          {'color': '#afafaf',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.00019417475728155,
#                           'spectrum': '#8c5fa8'}],
#               'commentary': None,
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'Gift of Edward W. Forbes',
#               'culture': 'Mesopotamian',
#               'datebegin': -2334,
#               'dated': 'c. 2334-2193 BCE',
#               'dateend': -2193,
#               'dateoffirstpageview': '2009-05-21',
#               'dateoflastpageview': '2020-01-14',
#               'department': 'Department of Ancient and Byzantine Art & '
#                             'Numismatics',
#               'description': 'A nude, bearded figure with curled locks '
#                              'grapples with an upright bull; to the other side '
#                              'of the inscription, the encounter of a lion and '
#                              'bull/bull-man is largely lost.',
#               'details': {'coins': {'dateonobject': None,
#                                     'denomination': None,
#                                     'dieaxis': None,
#                                     'metal': None,
#                                     'obverseinscription': None,
#                                     'reverseinscription': None}},
#               'dimensions': 'H. 3.8 cm (1 1/2 in.)',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 4,
#               'groupcount': 1,
#               'id': 291419,
#               'imagecount': 3,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC254191',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2450,
#                           'idsid': 48373902,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/48373902',
#                           'imageid': 434119,
#                           'publiccaption': 'detail',
#                           'renditionnumber': 'DDC254191',
#                           'width': 1694},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:STR018000',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 1955,
#                           'idsid': 400220302,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/400220302',
#                           'imageid': 444913,
#                           'publiccaption': 'impression of seal',
#                           'renditionnumber': 'STR018000',
#                           'width': 2550},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS44680_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 3,
#                           'format': 'image/jpeg',
#                           'height': 1024,
#                           'idsid': 20680719,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20680719',
#                           'imageid': 129765,
#                           'publiccaption': None,
#                           'renditionnumber': '44680',
#                           'width': 838}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:43:38-0500',
#               'markscount': 1,
#               'mediacount': 0,
#               'medium': 'Ferruginous Limestone',
#               'objectid': 291419,
#               'objectnumber': '1957.195',
#               'peoplecount': 0,
#               'period': 'Akkadian period',
#               'periodid': 2833,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC254191',
#               'provenance': 'Edward W. Forbes, Cambridge, MA, (by 1957), gift; '
#                             'to Fogg Art Museum, 1957.',
#               'publicationcount': 0,
#               'rank': 1,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/291419',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': 'Intaglio',
#               'techniqueid': 871,
#               'title': 'Cylinder Seal: Combat Scenes',
#               'titlescount': 2,
#               'totalpageviews': 593,
#               'totaluniquepageviews': 520,
#               'url': 'https://www.harvardartmuseums.org/collections/object/291419',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'seal', 'worktypeid': '318'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 1960,
#               'accesslevel': 1,
#               'century': '19th century',
#               'classification': 'Prints',
#               'classificationid': 23,
#               'colorcount': 8,
#               'colors': [{'color': '#e1c8c8',
#                           'css3': '#d8bfd8',
#                           'hue': 'Orange',
#                           'percent': 0.21881355932203,
#                           'spectrum': '#c15689'},
#                          {'color': '#646464',
#                           'css3': '#696969',
#                           'hue': 'Grey',
#                           'percent': 0.14468926553672,
#                           'spectrum': '#7866ad'},
#                          {'color': '#7d7d7d',
#                           'css3': '#808080',
#                           'hue': 'Grey',
#                           'percent': 0.13790960451977,
#                           'spectrum': '#8362aa'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.13135593220339,
#                           'spectrum': '#3db657'},
#                          {'color': '#c8c8af',
#                           'css3': '#c0c0c0',
#                           'hue': 'Green',
#                           'percent': 0.12242937853107,
#                           'spectrum': '#b55592'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.1180790960452,
#                           'spectrum': '#8761aa'},
#                          {'color': '#afaf96',
#                           'css3': '#a9a9a9',
#                           'hue': 'Green',
#                           'percent': 0.069774011299435,
#                           'spectrum': '#8e5ea7'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.056949152542373,
#                           'spectrum': '#2eb45d'}],
#               'commentary': None,
#               'contact': 'am_europeanamerican@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Program for '
#                             'Harvard College Fund',
#               'culture': 'French',
#               'datebegin': 1862,
#               'dated': '1862',
#               'dateend': 1862,
#               'dateoffirstpageview': '2009-07-04',
#               'dateoflastpageview': '2020-01-14',
#               'department': 'Department of Prints',
#               'description': None,
#               'dimensions': 'sheet: 48.6 x 62.3 cm (19 1/8 x 24 1/2 in.)',
#               'division': 'European and American Art',
#               'edition': None,
#               'exhibitioncount': 3,
#               'groupcount': 2,
#               'id': 272158,
#               'imagecount': 2,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC103413_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2009,
#                           'idsid': 20029119,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20029119',
#                           'imageid': 257842,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC103413',
#                           'width': 2550},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG42782_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 903,
#                           'idsid': 43162170,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43162170',
#                           'imageid': 122839,
#                           'publiccaption': None,
#                           'renditionnumber': 'LEG42782',
#                           'width': 1024}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:43:03-0500',
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': None,
#               'objectid': 272158,
#               'objectnumber': 'M13710',
#               'people': [{'alphasort': 'Manet, Edouard',
#                           'birthplace': 'Paris',
#                           'culture': 'French',
#                           'deathplace': 'Paris',
#                           'displaydate': '1832 - 1883',
#                           'displayname': 'Edouard Manet',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'Edouard Manet',
#                           'personid': 27349,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC103413_dynmc',
#               'provenance': None,
#               'publicationcount': 6,
#               'rank': 2,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/272158',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': 'G. 68, M-N. 76, Ber 63, H. 23',
#               'state': 'only state',
#               'style': None,
#               'technique': 'Lithograph',
#               'techniqueid': 136,
#               'title': 'The Balloon',
#               'titlescount': 2,
#               'totalpageviews': 640,
#               'totaluniquepageviews': 562,
#               'url': 'https://www.harvardartmuseums.org/collections/object/272158',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 1995,
#               'accesslevel': 1,
#               'century': '16th century',
#               'classification': 'Paintings',
#               'classificationid': 26,
#               'colorcount': 8,
#               'colors': [{'color': '#af4b4b',
#                           'css3': '#a0522d',
#                           'hue': 'Red',
#                           'percent': 0.31190476190476,
#                           'spectrum': '#d75776'},
#                          {'color': '#af7d64',
#                           'css3': '#cd5c5c',
#                           'hue': 'Brown',
#                           'percent': 0.28160714285714,
#                           'spectrum': '#c85783'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.11625,
#                           'spectrum': '#3db657'},
#                          {'color': '#c8af7d',
#                           'css3': '#d2b48c',
#                           'hue': 'Brown',
#                           'percent': 0.09625,
#                           'spectrum': '#e9715f'},
#                          {'color': '#64644b',
#                           'css3': '#696969',
#                           'hue': 'Green',
#                           'percent': 0.078095238095238,
#                           'spectrum': '#59ba4a'},
#                          {'color': '#e1c8af',
#                           'css3': '#f5deb3',
#                           'hue': 'Orange',
#                           'percent': 0.057857142857143,
#                           'spectrum': '#e9715f'},
#                          {'color': '#e1e1c8',
#                           'css3': '#dcdcdc',
#                           'hue': 'Green',
#                           'percent': 0.033571428571429,
#                           'spectrum': '#e9715f'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.024464285714286,
#                           'spectrum': '#2eb45d'}],
#               'commentary': None,
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'Gift in gratitude to John Coolidge, Gift of '
#                             'Leslie Cheek, Jr., Anonymous Fund in memory of '
#                             'Henry Berg, Louise Haskell Daly, Alpheus Hyatt, '
#                             'Richard Norton Memorial Funds and through the '
#                             'generosity of Albert H. Gordon and Emily Rauh '
#                             'Pulitzer; formerly in the collection of Stuart '
#                             'Cary Welch, Jr.',
#               'culture': 'Indian',
#               'datebegin': 1535,
#               'dated': 'c.1540',
#               'dateend': 1545,
#               'dateoffirstpageview': '2009-05-16',
#               'dateoflastpageview': '2020-01-14',
#               'department': 'Department of Islamic & Later Indian Art',
#               'description': None,
#               'dimensions': '17.9 x 24 cm (7 1/16 x 9 7/16 in.)',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 4,
#               'groupcount': 1,
#               'id': 1428,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:ISL10069_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 767,
#                           'idsid': 43534078,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43534078',
#                           'imageid': 120762,
#                           'publiccaption': None,
#                           'renditionnumber': 'ISL10069',
#                           'width': 1024}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:36:14-0500',
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Opaque watercolor on paper',
#               'objectid': 1428,
#               'objectnumber': '1995.66',
#               'people': [{'alphasort': 'Unknown Artist',
#                           'birthplace': None,
#                           'culture': None,
#                           'deathplace': None,
#                           'displaydate': None,
#                           'displayname': 'Unknown Artist',
#                           'displayorder': 1,
#                           'gender': 'unknown',
#                           'name': 'Unknown Artist',
#                           'personid': 23184,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:ISL10069_dynmc',
#               'provenance': None,
#               'publicationcount': 0,
#               'rank': 3,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/1428',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'Battle Scene, folio fragment from an album of the '
#                        'Bhagavata Purana (Ancient Stories of the Lord)a '
#                        'Bhagavat Purana series',
#               'titlescount': 1,
#               'totalpageviews': 710,
#               'totaluniquepageviews': 576,
#               'url': 'https://www.harvardartmuseums.org/collections/object/1428',
#               'verificationlevel': 0,
#               'verificationleveldescription': 'Unchecked. Object information '
#                                               'has not been verified for '
#                                               'completeness and has not been '
#                                               'vetted',
#               'worktypes': [{'worktype': 'manuscript', 'worktypeid': '208'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 1991,
#               'accesslevel': 1,
#               'century': '6th century',
#               'classification': 'Vessels',
#               'classificationid': 57,
#               'colorcount': 0,
#               'commentary': None,
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'Partial gift of Maria C. Henderson and partial '
#                             'purchase through the Ernest B. and Helen Pratt '
#                             'Dane Fund for the Acquisition of Oriental Art',
#               'culture': 'Korean',
#               'datebegin': 500,
#               'dated': 'first half 6th century',
#               'dateend': 550,
#               'dateoffirstpageview': '2009-08-05',
#               'dateoflastpageview': '2020-01-15',
#               'department': 'Department of Asian Art',
#               'description': None,
#               'dimensions': 'H. 15.4 x W. 10.9 x Diam (of wheel). 11.2 cm (6 '
#                             '1/16 x 4 5/16 x 4 7/16 in.)',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 1,
#               'groupcount': 2,
#               'id': 201597,
#               'imagecount': 2,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:DDC113947_dynmc',
#                           'copyright': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 43269056,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43269056',
#                           'imageid': 411037,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC113947',
#                           'width': 1889},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:CARP03515_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 904,
#                           'idsid': 20028085,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20028085',
#                           'imageid': 138329,
#                           'publiccaption': 'bottom view',
#                           'renditionnumber': 'CARP03515',
#                           'width': 1024}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:40:46-0500',
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Kaya-type ware: gray stoneware with appliqué and '
#                         'openwork decoration and with traces of natural ash '
#                         'glaze.  Reportedly recovered from a tomb in '
#                         "Hyŏnp'ung-myŏn, Talsŏng-gun, near Kyŏngju, North "
#                         'Kyŏngsang province, in July 1962.',
#               'objectid': 201597,
#               'objectnumber': '1991.512',
#               'peoplecount': 0,
#               'period': 'Three Kingdoms period, Silla or Kaya',
#               'periodid': 7400,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:DDC113947_dynmc',
#               'provenance': 'Gregory (1922-1988) and Maria C. Henderson '
#                             '(1923-2007), Medford, MA (by 1969-1988), '
#                             'inherited; by Maria C. Henderson, Medford, MA '
#                             '(1988-1991), partial gift and partial purchase; '
#                             'to Harvard University Art Museums, 1991.',
#               'publicationcount': 1,
#               'rank': 4,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/201597',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'Chariot Vessel with Two Cups, Two Openwork Wheels, and '
#                        'Openwork, Flaring Base',
#               'titlescount': 1,
#               'totalpageviews': 635,
#               'totaluniquepageviews': 555,
#               'url': 'https://www.harvardartmuseums.org/collections/object/201597',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'vessel', 'worktypeid': '389'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 1994,
#               'accesslevel': 1,
#               'century': '20th century',
#               'classification': 'Photographs',
#               'classificationid': 17,
#               'colorcount': 0,
#               'commentary': None,
#               'contact': 'am_moderncontemporary@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through '
#                             'the generosity of  Sylvan Barnet and William '
#                             'Burto in honor of John Rosenfield',
#               'culture': 'Japanese',
#               'datebegin': 1993,
#               'dated': '1993',
#               'dateend': 1993,
#               'dateoffirstpageview': '2009-05-27',
#               'dateoflastpageview': '2020-01-15',
#               'department': 'Department of Photographs',
#               'description': None,
#               'dimensions': 'image: 42.3 x 54 cm (16 5/8 x 21 1/4 in.)',
#               'division': 'Modern and Contemporary Art',
#               'edition': None,
#               'exhibitioncount': 3,
#               'groupcount': 1,
#               'id': 95201,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG1070_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 799,
#                           'idsid': 43155438,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43155438',
#                           'imageid': 94507,
#                           'publiccaption': None,
#                           'renditionnumber': 'LEG1070',
#                           'width': 1024}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:37:55-0500',
#               'markscount': 1,
#               'mediacount': 0,
#               'medium': None,
#               'objectid': 95201,
#               'objectnumber': 'P1994.7',
#               'people': [{'alphasort': 'Sugimoto, Hiroshi',
#                           'birthplace': 'Tokyo, Japan',
#                           'culture': 'Japanese',
#                           'deathplace': None,
#                           'displaydate': 'born 1948',
#                           'displayname': 'Hiroshi Sugimoto',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'Hiroshi Sugimoto',
#                           'personid': 35155,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG1070_dynmc',
#               'provenance': 'Sonnabend Gallery, New York, NY, from the artist, '
#                             'sold to Harvard University Art Museums, 1994. '
#                             'Sold through funds donated by (see credit)\r\n'
#                             'Hiroshi Sugimoto, through the Sonnabend Gallery, '
#                             'New York.\r\n',
#               'publicationcount': 2,
#               'rank': 5,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/95201',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': 'Hiroshi Sugimoto, 1993',
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': 'Gelatin silver print',
#               'techniqueid': 123,
#               'title': 'Metropolitan Orpheum, Los Angeles',
#               'titlescount': 1,
#               'totalpageviews': 711,
#               'totaluniquepageviews': 600,
#               'url': 'https://www.harvardartmuseums.org/collections/object/95201',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'}]},
#              {'accessionmethod': 'Partial Gift/Partial Purchase',
#               'accessionyear': 1991,
#               'accesslevel': 1,
#               'century': '4th century CE',
#               'classification': 'Sculpture',
#               'classificationid': 30,
#               'colorcount': 9,
#               'colors': [{'color': '#7d7d7d',
#                           'css3': '#808080',
#                           'hue': 'Grey',
#                           'percent': 0.34345238095238,
#                           'spectrum': '#8362aa'},
#                          {'color': '#e1e1e1',
#                           'css3': '#dcdcdc',
#                           'hue': 'Grey',
#                           'percent': 0.25690476190476,
#                           'spectrum': '#955ba5'},
#                          {'color': '#c8c8c8',
#                           'css3': '#c0c0c0',
#                           'hue': 'Grey',
#                           'percent': 0.15803571428571,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.13660714285714,
#                           'spectrum': '#8761aa'},
#                          {'color': '#afafaf',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.065714285714286,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#646464',
#                           'css3': '#696969',
#                           'hue': 'Grey',
#                           'percent': 0.020952380952381,
#                           'spectrum': '#7866ad'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.0086309523809524,
#                           'spectrum': '#3db657'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.0058333333333333,
#                           'spectrum': '#2eb45d'},
#                          {'color': '#191919',
#                           'css3': '#000000',
#                           'hue': 'Grey',
#                           'percent': 0.0038690476190476,
#                           'spectrum': '#1eb264'}],
#               'commentary': '',
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'Gift in part of Dr. and Mrs. Jerome Eisenberg and '
#                             'Purchase in part from the Alpheus Hyatt '
#                             'Purchasing Fund',
#               'culture': 'Roman',
#               'datebegin': 300,
#               'dated': '4th century CE',
#               'dateend': 400,
#               'dateoffirstpageview': '2009-08-11',
#               'dateoflastpageview': '2020-01-15',
#               'department': 'Department of Ancient and Byzantine Art & '
#                             'Numismatics',
#               'description': None,
#               'dimensions': '55 cm h x 48 cm w x 23 cm d (21 5/8 x 18 7/8 x 9 '
#                             '1/16 in.)',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 3,
#               'groupcount': 2,
#               'id': 287968,
#               'imagecount': 2,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC108008_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 13881578,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/13881578',
#                           'imageid': 349738,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC108008',
#                           'width': 1920},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:12802_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 1024,
#                           'idsid': 43181416,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181416',
#                           'imageid': 2590,
#                           'publiccaption': None,
#                           'renditionnumber': '12802',
#                           'width': 871}],
#               'labeltext': 'Ancient Greek drama had a long afterlife. The '
#                            'comic playwright Menander worked in the court of a '
#                            'Hellenistic ruler in the fourth to third centuries '
#                            'BCE, but his popularity endured into the late '
#                            'antique period and beyond; there are more ancient '
#                            'Menander portraits in existence than portraits of '
#                            'any other Greek writer or thinker. His own reputed '
#                            'skill at naturalistic portrayals may have made him '
#                            'such a desirable subject; Aristophanes of '
#                            'Byzantium famously wrote, “Oh Menander and Life! '
#                            'Which of you imitated the other?” This particular '
#                            'medallion portrait, produced long after the '
#                            'playwright’s death, would probably have been '
#                            'displayed in a Roman architectural context '
#                            'alongside similar portraits of Greek philosophers '
#                            'and playwrights. Menander, complete with dramatic '
#                            'scroll in the background, would have stood out for '
#                            'his urbane and vigorous features, and his '
#                            'clean-shaven chin would have contrasted with the '
#                            'beards of his more serious companions.',
#               'lastupdate': '2020-01-28T05:43:30-0500',
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Marble',
#               'objectid': 287968,
#               'objectnumber': '1991.63',
#               'peoplecount': 0,
#               'period': 'Roman Imperial period',
#               'periodid': 786,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC108008_dynmc',
#               'provenance': 'Hon. James Smith Barry, Marbury Hall, Cheshire, '
#                             'England, (acquired 1776), by descent; to the '
#                             'Marbury Hall Collection, (until 1987), sold; '
#                             "[through Christie's, London, July 10, 1987]; "
#                             '[through Royal-Athena Galleries, New York, '
#                             '1987-1991], sold and partial gift from Jerome '
#                             'Eisenberg; to the Harvard University Art Museums, '
#                             '1991.',
#               'publicationcount': 3,
#               'rank': 6,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/287968',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': 'Carved',
#               'techniqueid': 639,
#               'title': 'Medallion Portrait of Menander',
#               'titlescount': 1,
#               'totalpageviews': 772,
#               'totaluniquepageviews': 643,
#               'url': 'https://www.harvardartmuseums.org/collections/object/287968',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'sculpture', 'worktypeid': '317'}]},
#              {'accessionmethod': 'Gift',
#               'accessionyear': 2008,
#               'accesslevel': 1,
#               'century': '17th century',
#               'classification': 'Prints',
#               'classificationid': 23,
#               'colorcount': 7,
#               'colors': [{'color': '#c8c8c8',
#                           'css3': '#c0c0c0',
#                           'hue': 'Grey',
#                           'percent': 0.59849673202614,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#e1e1c8',
#                           'css3': '#dcdcdc',
#                           'hue': 'Green',
#                           'percent': 0.34411764705882,
#                           'spectrum': '#e9715f'},
#                          {'color': '#afafaf',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.026470588235294,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.01562091503268,
#                           'spectrum': '#8761aa'},
#                          {'color': '#7d7d7d',
#                           'css3': '#808080',
#                           'hue': 'Grey',
#                           'percent': 0.0077124183006536,
#                           'spectrum': '#8362aa'},
#                          {'color': '#646464',
#                           'css3': '#696969',
#                           'hue': 'Grey',
#                           'percent': 0.005359477124183,
#                           'spectrum': '#7866ad'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.0022222222222222,
#                           'spectrum': '#3db657'}],
#               'commentary': 'The Iconography is a collection of portrait '
#                             'prints made after drawings and paintings by van '
#                             'Dyck. Eighteen were etched by the artist himself, '
#                             'although the majority are engravings made by a '
#                             'variety of printmakers. This compilation of '
#                             'portraits of princes, politicians, soldiers, '
#                             'statesmen, scholars, art connoisseurs and most '
#                             'importantly artists, a survey of the most '
#                             'distinguished men and women of his time, went '
#                             'through many editions. The edition published by '
#                             "Martinus van den Enden during van Dyck's lifetime "
#                             'consisted of eighty portraits. Van Dyck prepared '
#                             'these prints by making oil sketches and drawings '
#                             'in black chalk, sometimes washed with brown '
#                             'ink. \r\n'
#                             '\r\n'
#                             'Many of these eighteen etched portraits by van '
#                             'Dyck are rare first state impressions, including '
#                             "this one of the artist's Self-Portrait. The "
#                             'majority of the other eighteen are depictions of '
#                             'artists as well, including Jan and Pieter '
#                             'Brueghel, Lucas Vorsterman and Paulus '
#                             'Pontius-important reproductive engravers of '
#                             "Rubens's work, and Cornelis Anthoniszoon.\r\n",
#               'contact': 'am_europeanamerican@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Walter '
#                             'C. Klein, Class of 1939',
#               'culture': 'Flemish',
#               'datebegin': 1621,
#               'dated': 'c. 1626-1633',
#               'dateend': 1631,
#               'dateoffirstpageview': '2009-11-04',
#               'dateoflastpageview': '2020-01-15',
#               'department': 'Department of Prints',
#               'description': None,
#               'dimensions': 'platemark: 24.5 x 15.7 cm (9 5/8 x 6 3/16 in.)\r\n'
#                             'sheet: 26 x 17.5 cm (10 1/4 x 6 7/8 in.)\r\n'
#                             'framed: 57.8 x 47 x 2.5 cm (22 3/4 x 18 1/2 x 1 '
#                             'in.)',
#               'division': 'European and American Art',
#               'edition': None,
#               'exhibitioncount': 1,
#               'groupcount': 2,
#               'id': 323716,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC105118_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 8720731,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/8720731',
#                           'imageid': 297840,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC105118',
#                           'width': 1740}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:44:44-0500',
#               'markscount': 3,
#               'mediacount': 0,
#               'medium': 'Etching on off-white antique laid paper',
#               'objectid': 323716,
#               'objectnumber': '2008.25.1',
#               'people': [{'alphasort': 'Dyck, Anthony van Sir',
#                           'birthplace': 'Antwerp, Belgium',
#                           'culture': 'Flemish',
#                           'deathplace': 'London',
#                           'displaydate': '1599 - 1641',
#                           'displayname': 'Anthony van Dyck',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'Anthony van Dyck',
#                           'personid': 19008,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC105118_dynmc',
#               'provenance': 'Sir Peter Lely (Lugt 2092). Cledenin J. Ryan, '
#                             'Short Hills, New Jersey, sold [through his sale, '
#                             'Parke Bernet, New York, January 19-20, 1940, lot '
#                             '112]. Mr. and Mrs. W. Clifford Klenk, Long '
#                             'Island, New York. [Sotheby Parke Bernet, New '
#                             'York, February 16, 1979, lot 610]. [R. M. Light & '
#                             'Co., Boston], sold; to Mr. and Mrs. Walter C. '
#                             'Klein, New York, gift; to Harvard Art Museums, '
#                             '2008.',
#               'publicationcount': 1,
#               'rank': 7,
#               'relatedcount': 17,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/323716',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': 'M.-H. 4; Antwerp/Amsterdam 5',
#               'state': 'i/vii',
#               'style': None,
#               'technique': 'Etching',
#               'techniqueid': 116,
#               'title': 'Self-Portrait',
#               'titlescount': 2,
#               'totalpageviews': 977,
#               'totaluniquepageviews': 794,
#               'url': 'https://www.harvardartmuseums.org/collections/object/323716',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]},
#              {'accessionmethod': 'Gift',
#               'accessionyear': 1984,
#               'accesslevel': 1,
#               'century': '19th century',
#               'classification': 'Manuscripts',
#               'classificationid': 185,
# ...
#               'verificationlevel': 2,
#               'verificationleveldescription': 'Adequate. Object is adequately '
#                                               'described but information may '
#                                               'not be vetted',
#               'worktypes': [{'worktype': 'manuscript', 'worktypeid': '208'}]},
#              {'accessionmethod': 'Gift',
#               'accessionyear': 2007,
#               'accesslevel': 1,
#               'century': '20th century',
#               'classification': 'Prints',
#               'classificationid': 23,
#               'colorcount': 9,
#               'colors': [{'color': '#af7d4b',
#                           'css3': '#cd853f',
#                           'hue': 'Yellow',
#                           'percent': 0.79893333333333,
#                           'spectrum': '#e9715f'},
#                          {'color': '#af1900',
#                           'css3': '#b22222',
#                           'hue': 'Red',
#                           'percent': 0.13553333333333,
#                           'spectrum': '#dd5872'},
#                          {'color': '#324b96',
#                           'css3': '#483d8b',
#                           'hue': 'Blue',
#                           'percent': 0.021066666666667,
#                           'spectrum': '#4072b8'},
#                          {'color': '#4b4b7d',
#                           'css3': '#483d8b',
#                           'hue': 'Violet',
#                           'percent': 0.014266666666667,
#                           'spectrum': '#5e6db3'},
#                          {'color': '#af4b19',
#                           'css3': '#a0522d',
#                           'hue': 'Red',
#                           'percent': 0.0138,
#                           'spectrum': '#e86e61'},
#                          {'color': '#af6432',
#                           'css3': '#a0522d',
#                           'hue': 'Orange',
#                           'percent': 0.0069333333333333,
#                           'spectrum': '#e9715f'},
#                          {'color': '#64647d',
#                           'css3': '#696969',
#                           'hue': 'Blue',
#                           'percent': 0.0047333333333333,
#                           'spectrum': '#7069af'},
#                          {'color': '#7d324b',
#                           'css3': '#a52a2a',
#                           'hue': 'Red',
#                           'percent': 0.0029333333333333,
#                           'spectrum': '#b25593'},
#                          {'color': '#963232',
#                           'css3': '#a52a2a',
#                           'hue': 'Red',
#                           'percent': 0.0018,
#                           'spectrum': '#d0577c'}],
#               'commentary': None,
#               'contact': 'am_moderncontemporary@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Vivian '
#                             'and Lionel Spiro',
#               'culture': 'American',
#               'datebegin': 1969,
#               'dated': '1969',
#               'dateend': 1969,
#               'dateoffirstpageview': '2009-05-25',
#               'dateoflastpageview': '2020-01-15',
#               'department': 'Department of Prints',
#               'description': None,
#               'dimensions': 'sheet: 76.1 x 50.7 cm (29 15/16 x 19 15/16 in.)',
#               'division': 'Modern and Contemporary Art',
#               'edition': None,
#               'exhibitioncount': 0,
#               'groupcount': 2,
#               'id': 318040,
#               'imagecount': 2,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104099_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 20380053,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20380053',
#                           'imageid': 268978,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC104099',
#                           'width': 1699},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV141031_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 20305700,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20305700',
#                           'imageid': 234532,
#                           'publiccaption': None,
#                           'renditionnumber': 'INV141031',
#                           'width': 1725}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:44:35-0500',
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': None,
#               'objectid': 318040,
#               'objectnumber': '2007.8',
#               'people': [{'alphasort': 'Strike Poster Workshop',
#                           'birthplace': None,
#                           'culture': None,
#                           'deathplace': None,
#                           'displaydate': None,
#                           'displayname': 'Strike Poster Workshop',
#                           'displayorder': 1,
#                           'gender': 'unknown',
#                           'name': 'Strike Poster Workshop',
#                           'personid': 50996,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104099_dynmc',
#               'provenance': None,
#               'publicationcount': 0,
#               'rank': 9,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/318040',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': 'Screen print',
#               'techniqueid': 306,
#               'title': 'Strike with Fist',
#               'titlescount': 1,
#               'totalpageviews': 1044,
#               'totaluniquepageviews': 756,
#               'url': 'https://www.harvardartmuseums.org/collections/object/318040',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 2006,
#               'accesslevel': 1,
#               'century': '19th century',
#               'classification': 'Prints',
#               'classificationid': 23,
#               'colorcount': 9,
#               'colors': [{'color': '#c8c8c8',
#                           'css3': '#c0c0c0',
#                           'hue': 'Grey',
#                           'percent': 0.66526984126984,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#c8c864',
#                           'css3': '#bdb76b',
#                           'hue': 'Green',
#                           'percent': 0.1295873015873,
#                           'spectrum': '#b0d136'},
#                          {'color': '#afaf96',
#                           'css3': '#a9a9a9',
#                           'hue': 'Green',
#                           'percent': 0.11333333333333,
#                           'spectrum': '#8e5ea7'},
#                          {'color': '#4b647d',
#                           'css3': '#696969',
#                           'hue': 'Blue',
#                           'percent': 0.06247619047619,
#                           'spectrum': '#536fb5'},
#                          {'color': '#7d9696',
#                           'css3': '#778899',
#                           'hue': 'Green',
#                           'percent': 0.008,
#                           'spectrum': '#7069af'},
#                          {'color': '#7d7d64',
#                           'css3': '#808080',
#                           'hue': 'Yellow',
#                           'percent': 0.0073015873015873,
#                           'spectrum': '#6cbd45'},
#                          {'color': '#96967d',
#                           'css3': '#808080',
#                           'hue': 'Green',
#                           'percent': 0.0068571428571429,
#                           'spectrum': '#8e5ea7'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.0038095238095238,
#                           'spectrum': '#3db657'},
#                          {'color': '#64644b',
#                           'css3': '#696969',
#                           'hue': 'Green',
#                           'percent': 0.0033650793650794,
#                           'spectrum': '#59ba4a'}],
#               'commentary': None,
#               'contact': 'am_europeanamerican@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Dr. '
#                             'Ernest G. Stillman, Class of 1907, by exchange',
#               'culture': 'American',
#               'datebegin': 1890,
#               'dated': '1890-1891',
#               'dateend': 1891,
#               'dateoffirstpageview': '2009-06-13',
#               'dateoflastpageview': '2020-01-15',
#               'department': 'Department of Prints',
#               'description': None,
#               'dimensions': 'plate: 31.9 x 24.9 cm (12 9/16 x 9 13/16 in.)\r\n'
#                             'sheet: 43.5 x 30.4 cm (17 1/8 x 11 15/16 in.)',
#               'division': 'European and American Art',
#               'edition': '25',
#               'exhibitioncount': 2,
#               'groupcount': 2,
#               'id': 6108,
#               'imagecount': 3,
#               'imagepermissionlevel': 0,
#               'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC250728_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 46576403,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/46576403',
#                           'imageid': 427397,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC250728',
#                           'width': 1786},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC100021_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 18737571,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18737571',
#                           'imageid': 187383,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC100021',
#                           'width': 1793},
#                          {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV100983_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'displayorder': 3,
#                           'format': 'image/jpeg',
#                           'height': 1024,
#                           'idsid': 20223285,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20223285',
#                           'imageid': 186495,
#                           'publiccaption': None,
#                           'renditionnumber': 'INV100983',
#                           'width': 720}],
#               'labeltext': None,
#               'lastupdate': '2020-01-28T05:36:18-0500',
#               'markscount': 3,
#               'mediacount': 0,
#               'medium': None,
#               'objectid': 6108,
#               'objectnumber': '2006.24.1',
#               'people': [{'alphasort': 'Cassatt, Mary',
#                           'birthplace': 'Allegheny City, PA',
#                           'culture': 'American',
#                           'deathplace': 'Le Mesnil-Theribus, France',
#                           'displaydate': '1844 - 1926',
#                           'displayname': 'Mary Cassatt',
#                           'displayorder': 1,
#                           'gender': 'female',
#                           'name': 'Mary Cassatt',
#                           'personid': 31481,
#                           'prefix': None,
#                           'role': 'Artist'},
#                          {'alphasort': 'Leroy, Modeste',
#                           'birthplace': None,
#                           'culture': 'French',
#                           'deathplace': None,
#                           'displaydate': None,
#                           'displayname': 'Modeste Leroy',
#                           'displayorder': 2,
#                           'gender': 'male',
#                           'name': 'Modeste Leroy',
#                           'personid': 26485,
#                           'prefix': None,
#                           'role': 'Printer'}],
#               'peoplecount': 2,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC250728_dynmc',
#               'provenance': 'The artist; to Ambrose Vollard, Paris, 1926, '
#                             'bequest; to his heirs, 1939, sold; to Henri M. '
#                             'Petiet, Paris (Lugt 2021a), 1940, bequest; to his '
#                             'estate, 1980, sold; to Marc Rosen, New York, '
#                             'sold; to Harvard Art Museums, 2006\r\n',
#               'publicationcount': 2,
#               'rank': 10,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/6108',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': 'B. 143; Mathews/Shapiro 5',
#               'state': 'xvii/xvii (final)',
#               'style': None,
#               'technique': 'Drypoint, softground etching and aquatint',
#               'techniqueid': 4124,
#               'title': 'The Bath',
#               'titlescount': 1,
#               'totalpageviews': 1105,
#               'totaluniquepageviews': 834,
#               'url': 'https://www.harvardartmuseums.org/collections/object/6108',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]}]}

# %% [markdown]
# That's it. Really, we are done here. Everyone go home!
#
# OK not really, there is still more we can lean. But you have to admit
# that was pretty easy. If you can identify a service that returns the
# data you want in structured from, web scraping becomes a pretty
# trivial enterprise. We'll discuss several other scenarios and topics,
# but for some web scraping tasks this is really all you need to know.
#
# ### Organizing and saving the data
#
# The records we retrieved from
# `https://www.harvardartmuseums.org/browse` are arranged as a list of
# dictionaries. We can easily select the fields of arrange these data
# into a pandas `DataFrame` to facilitate subsequent analysis.

# %%
import pandas as pd

# %%
records1 = pd.DataFrame.from_records(collections1['records'])

# %%
print(records1)
# Out:
#                  accessionmethod  accessionyear  ...   verificationleveldescription                      worktypes
# 0                           Gift           1957  ...  Good. Object is well descr...  [{'worktypeid': '318', 'wo...
# 1                       Purchase           1960  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 2                       Purchase           1995  ...  Unchecked. Object informat...  [{'worktypeid': '208', 'wo...
# 3                       Purchase           1991  ...  Good. Object is well descr...  [{'worktypeid': '389', 'wo...
# 4                       Purchase           1994  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 5  Partial Gift/Partial Purchase           1991  ...  Good. Object is well descr...  [{'worktypeid': '317', 'wo...
# 6                           Gift           2008  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 7                           Gift           1984  ...  Adequate. Object is adequa...  [{'worktypeid': '208', 'wo...
# 8                           Gift           2007  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 9                       Purchase           2006  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
#
# [10 rows x 62 columns]

# %% [markdown]
# and write the data to a file.

# %%
records1.to_csv("records1.csv")

# %% [markdown]
# ### Iterating to retrieve all the data
#
# Of course we don't want just the first page of collections. How can we
# retrieve all of them?
#
# Now that we know the web service works, and how to make requests in
# Python, we can iterate in the usual way.

# %%
records = []
for offset in range(0, 50, 10):
    param_values = {'load_amount': 10, 'offset': offset}
    current_request = requests.get(collection_url, params = param_values)
    records += current_request.json()['records']

# %%
## convert list of dicts to a `DataFrame`
records_final = pd.DataFrame.from_records(records)

# %%
# write the data to a file.
records_final.to_csv("records_final.csv")

# %%
print(records_final)
# Out:
#                   accessionmethod  accessionyear  ...   verificationleveldescription                      worktypes
# 0                            Gift         1957.0  ...  Good. Object is well descr...  [{'worktypeid': '318', 'wo...
# 1                        Purchase         1960.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 2                        Purchase         1995.0  ...  Unchecked. Object informat...  [{'worktypeid': '208', 'wo...
# 3                        Purchase         1991.0  ...  Good. Object is well descr...  [{'worktypeid': '389', 'wo...
# 4                        Purchase         1994.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 5   Partial Gift/Partial Purchase         1991.0  ...  Good. Object is well descr...  [{'worktypeid': '317', 'wo...
# 6                            Gift         2008.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 7                            Gift         1984.0  ...  Adequate. Object is adequa...  [{'worktypeid': '208', 'wo...
# 8                            Gift         2007.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 9                        Purchase         2006.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 10                       Purchase         2008.0  ...  Best. Object is extensivel...  [{'worktypeid': '242', 'wo...
# 11                           Gift         2009.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 12                        Bequest         1943.0  ...  Best. Object is extensivel...  [{'worktypeid': '340', 'wo...
# 13                       Purchase         2009.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 14                           Gift         1933.0  ...  Adequate. Object is adequa...  [{'worktypeid': '278', 'wo...
# 15                        Bequest         1943.0  ...  Good. Object is well descr...  [{'worktypeid': '239', 'wo...
# 16                           Gift         1995.0  ...  Best. Object is extensivel...  [{'worktypeid': '346', 'wo...
# 17                           Gift         2008.0  ...  Good. Object is well descr...  [{'worktypeid': '242', 'wo...
# 18                       Purchase         2006.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 19                        Bequest         1932.0  ...  Best. Object is extensivel...  [{'worktypeid': '125', 'wo...
# 20                           Gift         1939.0  ...  Best. Object is extensivel...  [{'worktypeid': '125', 'wo...
# 21                       Purchase         2010.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 22                           None            NaN  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 23                        Bequest         1943.0  ...  Best. Object is extensivel...  [{'worktypeid': '317', 'wo...
# 24                           Gift         1951.0  ...  Adequate. Object is adequa...  [{'worktypeid': '138', 'wo...
# 25                        Bequest         1943.0  ...  Good. Object is well descr...  [{'worktypeid': '139', 'wo...
# 26                       Purchase         2008.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 27                       Purchase         2007.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 28                           Gift         1999.0  ...  Good. Object is well descr...  [{'worktypeid': '125', 'wo...
# 29                       Purchase         2008.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 30                           Gift         1977.0  ...  Adequate. Object is adequa...  [{'worktypeid': '71', 'wor...
# 31                       Purchase         2000.0  ...  Good. Object is well descr...  [{'worktypeid': '125', 'wo...
# 32                           Gift         1999.0  ...  Good. Object is well descr...  [{'worktypeid': '243', 'wo...
# 33                       Purchase         1972.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 34                       Purchase         2000.0  ...  Good. Object is well descr...  [{'worktypeid': '242', 'wo...
# 35                           Gift         1942.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 36                       Transfer         2011.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 37                           Gift         2009.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 38                           Gift         1928.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 39                       Transfer         2011.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 40                       Purchase         2010.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 41                           None            NaN  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 42                       Purchase         2010.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 43                       Purchase         2007.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 44                           Gift         2002.0  ...  Good. Object is well descr...  [{'worktypeid': '100', 'wo...
# 45                           Gift         2004.0  ...  Good. Object is well descr...  [{'worktypeid': '278', 'wo...
# 46                       Purchase         2010.0  ...  Good. Object is well descr...  [{'worktypeid': '259', 'wo...
# 47                           Gift         1949.0  ...  Good. Object is well descr...  [{'worktypeid': '125', 'wo...
# 48                        Bequest         1919.0  ...  Good. Object is well descr...  [{'worktypeid': '389', 'wo...
# 49                           Gift         1995.0  ...  Good. Object is well descr...  [{'worktypeid': '346', 'wo...
#
# [50 rows x 62 columns]

# %% [markdown]
# ### Exercise: Retrieve exhibits data
# In this exercise you will retrieve information about the art
# exhibitions at Harvard Art Museums from
# `https://www.harvardartmuseums.org/visit/exhibitions`
#
# 1. Using a web browser (Firefox or Chrome recommended) inspect the
#    page at `https://www.harvardartmuseums.org/visit/exhibitions`. Examine
#    the network traffic as you interact with the page. Try to find
#    where the data displayed on that page comes from.
# 2. Make a `get` request in Python to retrieve the data from the URL
#    identified in step1.
# 3. Write a *loop* or *list comprehension* in Python to retrieve data
#    for the first 5 pages of exhibitions data.
# 4. Bonus (optional): Convert the data you retrieved into a pandas
#   `DataFrame` and save it to a `.csv` file.
#
#
#
# ## Parse html if you have to
# As we've seen, you can often inspect network traffic or other sources
# to locate the source of the data you are interested in and the API
# used to retrieve it. You should always start by looking for these
# shortcuts and using them where possible. If you are really lucky,
# you'll find a shortcut that returns the data as JSON or XML. If you
# are not quite so lucky, you will have to parse HTML to retrieve the
# information you need.
#
# For example, when I inspected the network traffic while interacting
# with <https://www.harvardartmuseums.org/visit/calendar> I didn't see
# any requests that returned JSON data. The best we can do appears to be
# <https://www.harvardartmuseums.org/visit/calendar?date=>, which
# unfortunately returns  HTML.
#
# ### Retrieving HTML
# The first step is the same as before: we make at `GET` request.

# %%
calendar_path = 'visit/calendar'

calendar_url = (museum_domain # recall that we defined museum_domain earlier
                  + "/"
                  + calendar_path)

print(calendar_url)

events0 = requests.get(calendar_url, params = {'date': '2018-11'})
# Out:
# 'https://www.harvardartmuseums.org/visit/calendar'

# %% [markdown]
# As before we can check the headers to see what type of content we
# received in response to our request.

# %%
events0.headers['Content-Type']
# Out:
# 'text/html; charset=UTF-8'

# %% [markdown]
# ### Parsing HTML using the lxml library
# Like JSON, HTML is structured; unlike JSON it is designed to be
# rendered into a human-readable page rather than simply to store and
# exchange data in a computer-readable format. Consequently, parsing
# HTML and extracting information from it is somewhat more difficult
# than parsing JSON.
#
# While JSON parsing is built into the Python `requests` library, parsing
# HTML requires a separate library. I recommend using the HTML parser
# from the `lxml` library; others prefer an alternative called
# `BeautyfulSoup`.

# %%
from lxml import html

events_html = html.fromstring(events0.text)

# %% [markdown]
# ### Using xpath to extract content from HTML
# `XPath` is a tool for identifying particular elements withing a HTML
# document. The developer tools built into modern web browsers make it
# easy to generate `XPath`s that can used to identify the elements of a
# web page that we wish to extract.
#
# We can open the html document we retrieved and inspect it using
# our web browser.

# %%
html.open_in_browser(events_html, encoding = 'UTF-8')
# Out:
# file:///tmp/tmpimub2c3f.html

# %% [markdown]
# ![](img/dev_tools_right_click.png)
#
# ![](img/dev_tools_inspect.png)
#
# Once we identify the element containing the information of interest we
# can use our web browser to copy the `XPath` that uniquely identifies
# that element.
#
# ![](img/dev_tools_xpath.png)
#
# Next we can use python to extract the element of interest:

# %%
events_list_html = events_html.xpath('//*[@id="events_list"]')[0]

# %% [markdown]
# Once again we can use a web browser to inspect the HTML we're
# currently working with, and to figure out what we want to extract from
# it. Let's look at the first element in our events list.

# %%
first_event_html = events_list_html[0]
html.open_in_browser(first_event_html, encoding = 'UTF-8')

# %% [markdown]
# As before we can use our browser to find the xpath of the elements we
# want.
#
# ![](img/dev_tools_figcaption.png)
#
# (Note that the `html.open_in_browser` function adds enclosing `html`
# and `body` tags in order to create a complete web page for viewing.
# This requires that we adjust the `xpath` accordingly.)
#
# By repeating this process for each element we want, we can build a
# list of the xpaths to those elements.

# %%
elements_we_want = {'figcaption': 'div/figure/div/figcaption',
                    'date': 'div/div/header/time',
                    'title': 'div/div/header/h2/a',
                    'time': 'div/div/div/p[1]/time',
                    'localtion1': 'div/div/div/p[2]/span/span[1]',
                    'location2': 'div/div/div/p[2]/span/span[2]'
                    }

# %% [markdown]
# Finally, we can iterate over the elements we want and extract them.

# %%
first_event_values = {}
for key in elements_we_want.keys():
    element = first_event_html.xpath(elements_we_want[key])[0]
    first_event_values[key] = element.text_content().strip()

print(first_event_values)

# %% [markdown]
# ### Iterating to retrieve content from a list of HTML elements
# So far we've retrieved information only for the first event. To
# retrieve data for all the events listed on the page we need to iterate
# over the events. If we are very lucky, each event will have exactly
# the same information structured in exactly the same way and we can
# simply extend the code we wrote above to iterate over the events list.
#
# Unfortunately not all these elements are available for every event, so
# we need to take care to handle the case where one or more of these
# elements is not available. We can do that by defining a function that
# tries to retrieve a value and returns an empty string if it fails.

# %%
def get_event_info(event, path):
    try:
        info = event.xpath(path)[0].text.strip()
    except:
        info = ''
    return info

# %% [markdown]
# Armed with this function we can iterate over the list of events and
# extract the available information for each one.

# %%
all_event_values = {}
for key in elements_we_want.keys():
    key_values = []
    for event in events_list_html: 
        key_values.append(get_event_info(event, elements_we_want[key]))
    all_event_values[key] = key_values

# %% [markdown]
# For convenience we can arrange these values in a pandas `DataFrame`
# and save them as .csv files, just as we did with our exhibitions data earlier.

# %%
all_event_values = pd.DataFrame.from_dict(all_event_values)

all_event_values.to_csv("all_event_values.csv")

print(all_event_values)

# %% [markdown]
# ### Exercise: parsing HTML
# In this exercise you will retrieve information about the physical
# layout of the Harvard Art Museums. The web page at
# <https://www.harvardartmuseums.org/visit/floor-plan> contains this
# information in HTML from.
#
# 1. Using a web browser (Firefox or Chrome recommended) inspect the
#    page at `https://www.harvardartmuseums.org/visit/floor-plan`. Copy
#    the `XPath` to the element containing the list of level
#    information. (HINT: the element if interest is a `ul`, i.e.,
#    `unordered list`.)
# 2. Make a `get` request in Python to retrieve the web page at
#    <https://www.harvardartmuseums.org/visit/floor-plan>. Extract the
#    content from your request object and parse it using `html.fromstring`
#    from the `lxml` library.
# 3. Use your web browser to find the `XPath`s to the facilities housed on
#    level one. Use Python to extract the text from those `Xpath`s.
# 4. Bonus (optional): Write a *loop* or *list comprehension* in Python
#    to retrieve data for all the levels.

# %% [markdown]
# ## Use Scrapy for large or complicated projects
# Scraping websites using the `requests` library to make GET and POST
# requests, and the `lxml` library to process HTML is a good way to
# learn basic web scraping techniques. It is a good choice for small to
# medium size projects. For very large or complicated scraping tasks the
# `scrapy` library offers a number of conveniences, including
# asynchronously retrieval, session management, convenient methods for
# extracting and storing values, and more. More information about
# `scrapy` can be found at <https://doc.scrapy.org>.
#
# ## Use a browser driver as a last resort
# It is sometimes necessary (or sometimes just easier) to use a web
# browser as an intermediary rather than communicating directly with a
# web service. This method has the advantage of being about to use the
# javascript engine and session management features of a web browser;
# the main disadvantage is that it is slower and tends to be more
# fragile than using `requests` or `scrapy` to make requests directly
# from python. For small scraping projects involving complicated sites
# with CAPTHAs or lots of complicated javascript using a browser driver
# can be a good option. More information is available at
# <https://www.seleniumhq.org/docs/03_webdriver.jsp>.
